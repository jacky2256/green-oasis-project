# %%
import pandas as pd

# %%
df = pd.read_json('shraby.json')
df.head(100)
# Out:
#             title_en                             title_ru      color    aroma  \
# 0   Agnes Schilliger                      Агнес Шиллингер    Розовый  Сильный
# 1                     Александра принцесса Люксембургская    Розовый  Средний
# 2                                          Амандин Шанель    Розовый  Средний
# 3       Anny Duperey                          Анни Дюпрей     Желтый  сильный
# 4                                                 Артемис      Белый  Сильный
# ..               ...                                  ...        ...      ...
# 74                                         Шарль де Нерво   Кремовые  Сильный
# 75                                         Шато де Вертой    Розовый   Слабый
# 76                                           Шерлок Холмс  Оранжевый  Средний
# 77                                          Элоди Госсюэн    Розовый  Сильный
# 78                                 Ютерсенс Розенпринцесс    Розовый   Слабый
#
# ...
